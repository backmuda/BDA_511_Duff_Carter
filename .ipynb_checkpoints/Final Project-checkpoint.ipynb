# %% [markdown]
# # Final Project BDA 511 -- Zach Duff, Wyatt Carter
#
# ----
# ---
#
# ## **1. Data Preparation**
#
# ---
#
# The first thing we need to do is find a good way to read our housing data, so that we can make use of it. So let's import the Python tools we'll be using (also the math ones used later on):

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt
from matplotlib import pyplot

a4_dims = (11.7, 8.27)

import warnings
warnings.filterwarnings("ignore") # Annoyed by deprecation warnings.


def RMSE(predictor_var, target_var):
    n = max(predictor_var.shape)
    E = np.sqrt(np.sum(np.square(predictor_var - target_var)) / float(n))
    return E

# %% [markdown]
# We'll use ```pandas``` to grab the data from the csv files and place them into pandas dataframes.

# %%
train_file = "train_data.csv"
test_file = "test_data.csv"

# pandas dataframes
df_train = pd.read_csv(train_file, header=0)
df_test = pd.read_csv(test_file, header=0)

# %% [markdown]
# Below is an example of the ```pandas``` dataframe structure.

# %%
df_train[:10] #First 10 rows of our training data
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# It's now clear that we have both numerical and non numerical data. We can display data type in each column of our data with ```pandas.dtypes```.

# %%
df_train.dtypes[:10]
# Out:
# Id               int64
# MSSubClass       int64
# MSZoning        object
# LotFrontage    float64
# LotArea          int64
# Street          object
# Alley           object
# LotShape        object
# LandContour     object
# Utilities       object
# dtype: object

# %% [markdown]
# Or more specifically:

# %%
df_train.get_dtype_counts()
# Out:
# float64     3
# int64      35
# object     43
# dtype: int64

# %% [markdown]
# We'll need different of models for these different data types. Also, we can see that some of our features contain values of ```NaN```. These ```NaN```'s were converted, via ```pandas``` from missing data (_NA_'s) in our csv file, so we'll have to be wary of that as well.
#
# ### **1.1 A Quick Look at the Target Variable**
# ---
#
# Since our main objective is predict housing price data, let's take a look at housing prices alone. After all, a simple average _is_ a crude predictor.

# %%
# Dependent Variables

from matplotlib.ticker import FormatStrFormatter

fig, ax = pyplot.subplots(figsize=a4_dims)
ax = sns.distplot(df_train['SalePrice']);
ax.xaxis.set_major_formatter(FormatStrFormatter('$%d'))
ax.locator_params(nbins=4)

print("Number of Training Samples: %s" % len(df_train))
print("Mean Training House Price: " + "${:,.2f}".format(df_train.SalePrice.mean()))
print("Median: " + "${:,.2f}".format(df_train.SalePrice.median()))
      
print("Standard Deviation: " + "${:,.2f}".format(df_train.SalePrice.std()))
print("Skew: %.4f:" % df_train.SalePrice.skew()) # Symmetry about the mean
print("Kurtosis: %.4f" % df_train.SalePrice.kurt()) # "Tailedness"
# Out:
# Number of Training Samples: 1460
# Mean Training House Price: $180,921.20
# Median: $163,000.00
# Standard Deviation: $79,442.50
# Skew: 1.8829:
# Kurtosis: 6.5363

# %% [markdown]
# A couple mentions on the distribution. It does not appear to be exactly normal, which will not work well with standard ML algorithms [SOURCE]. Therefore we may choose to drop the extremely priced houses we can see around the $750k mark, for training purpose. But for now, let's continue.
#
# ---
#
# With the average training house price in hand we can make a informed, albeit barbaric, prediction about the values of our test data. If we predict that a test house chosen at random from our test data is $\bar{y} = 180,921$ we can measure how wrong we were using the root mean square error (aka RMSE):
#
# $$E_0 = \frac{1}{1460}\sqrt{\sum_{i=0}^{1459}\left(y^i - \bar{y} \right)^2}$$
#
# Implemented in python:

# %%
y_train = df_train.SalePrice.values
train_mean = df_train.SalePrice.mean()
E0 = RMSE(y_train, train_mean)

print("Root Mean Square Error: " + "${:,.2f}".format(E0) + '\n')
# Out:
# Root Mean Square Error: $79,415.29

# %% [markdown]
# We could use alternate error formulas such as the Root Median Square Error or Mean Absolue Error (shown below). But the norm-styled error are equivalent anyways (p-norms are equivalent), and in the spirit of the Kaggle competition we'll stick with RMSE.

# %%
mae = np.sum([abs(train_mean - y) for y in y_train]) / 1460.
print("Mean Absolute Error: " + "${:,.2f}".format(mae) + '\n')
# Out:
# Mean Absolute Error: $57,434.77

# %% [markdown]
# So, we were off by about \\$57,434.77 on average. Let's move on to more sophisticated methods to see if we can improve our score.
#
# ### **1.2. Data Cleansing**

# %% [markdown]
# Before we train our model, we'll spend some time to clean up our training data. We'll decide which dimensions are going to be most useful (since there's 80 of them) in the prediction of housing price. As mentioned earlier, we noticed that some of our variables included categorical data, so for now, we'll ignore those dimension and look at stuff that has numerical data only. We'll also drop the MSSubclass feature, since even though it's entries are numbers, those numbers are actually classification types.
#
# In order to accomplis this we'll use ```pandas``` to filter our data.

# %%
# Get Numeric Features (not necessarily useful)
df_train_num = df_train.select_dtypes(include=['float64', 'int64'])

df_train_num = df_train_num.drop(labels=['MSSubClass', 'Id'], axis=1)

# %%
df_train_num[:10]
# Out:
#    LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0         65.0     8450            7            5       2003          2003
# 1         80.0     9600            6            8       1976          1976
# 2         68.0    11250            7            5       2001          2002
# 3         60.0     9550            7            5       1915          1970
# 4         84.0    14260            8            5       2000          2000
# 5         85.0    14115            5            5       1993          1995
# 6         75.0    10084            8            5       2004          2005
# 7          NaN    10382            7            6       1973          1973
# 8         51.0     6120            7            5       1931          1950
# 9         50.0     7420            5            6       1939          1950
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF    ...      WoodDeckSF  \
# ...

# %% [markdown]
# Lastly, let's remove all rows that contain ```NaN``` values. And at the same time

# %%
df_train_num = df_train_num.dropna()
print("Dimensions of remaining (good) data: [%s, %s] \n" % (df_train_num.shape[0], df_train_num.shape[1]))
# Out:
# Dimensions of remaining (good) data: [1121, 36]

# %% [markdown]
# So now we have 35 numerical variables (not all continuous) with 1121 completed filled rows (entries for each variable). This is essentially a "pure" section of our training data. We have to be careful here though because a value of ```NaN``` might be included in one of these dimensions for our test data, so we'll need a way to handle that later on.
#
# ### 2. Data Exploration
#
# First, to get a feel for our data -- and for fun -- we'll visualize it with a histogram. Below is are the histograms of all of our 35 numerical predictors.

# %%
df_train_num.loc[:, : 'BsmtUnfSF'].hist(bins=35, figsize=(20,15)); # colon suppresses printing metadata
df_train_num.columns
# Out:
# Index(['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# Sort of what we, expected. We have a couple seemingly normal distributions in variables like _1stFlrSF_, which is first floor square footage; and we accidentally included our target variable _SalePrice_, which has already been noted as mostly normal.
#
# ---
# ---

# %% [markdown]
# Ultimately we'll want to predict housing price based on as little information as possible. That is, we aim to eliminate predictor variables that are strongly linearly correlated with others, thereby reducing our predictor dimensions into those that are unrelated, or are orthogonal.
#
# In order to achieve this we'll find the dimensions in our data that are most strongly correlated and discard the other. Below, we've built a heat map indicating which feature variables are strongly correlated. Blue is associated with negative correlation and red with positive correlation. [The correlation coeffcient used was Pearson's.](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.corr.html)

# %%
corr = df_train_num.corr() # Pearson
fig = plt.figure()
fig.set_size_inches([16., 13.])
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df_train_num.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(df_train_num.columns, fontsize=14)
ax.set_yticklabels(df_train_num.columns, fontsize=14)
plt.show()

# %% [markdown]
# In the heatmap we note a few things:
#
# * Anything correlated with itself has a correlation coefficient of 1. This information is of little value.
# * The map is symmetric, as it should be.
# * As suspected, strongly correlated items appear redundant. For example, the variables _GarageYrBlt_ and _YearBuilt_ have a strong correlation, and the square footage of finished basements in our test homes are negatively correlated with the squre footage of unfinished basements.
#
# In light of these observations, we would like to choose dimensions for our model that do not appear to be strongly correlated (neutral grayish color). At the same time we want to select the uncorrelated variables that we believe apply to most homes. **Warning**: Just because two items aren't linearly correlated does not mean that they are not correlated, so we might be missing some valuable info, by only using this specific set of correlation data.

# %%
c = corr.abs().unstack() # All made positive for ease of view.
c = c.sort_values(kind="quicksort")
c[-34:0:-2]
# Out:
# GrLivArea      GrLivArea       1.000000
# LotFrontage    LotFrontage     1.000000
# GarageCars     GarageArea      0.839415
# TotalBsmtSF    1stFlrSF        0.835999
# TotRmsAbvGrd   GrLivArea       0.824312
# YearBuilt      GarageYrBlt     0.823520
# SalePrice      OverallQual     0.797881
# GrLivArea      SalePrice       0.705154
#                2ndFlrSF        0.688292
# BsmtFullBath   BsmtFinSF1      0.651727
# TotRmsAbvGrd   BedroomAbvGr    0.650285
# GarageCars     SalePrice       0.647034
# GarageYrBlt    YearRemodAdd    0.645808
# YearRemodAdd   YearBuilt       0.623171
# SalePrice      GarageArea      0.619330
# TotRmsAbvGrd   2ndFlrSF        0.617776
# SalePrice      TotalBsmtSF     0.615612
# GrLivArea      FullBath        0.614887
# SalePrice      1stFlrSF        0.607969
# OverallQual    GrLivArea       0.607466
# HalfBath       2ndFlrSF        0.606337
# GarageCars     GarageYrBlt     0.600903
# OverallQual    GarageCars      0.593803
# ...

# %% [markdown]
# We note that entries at the carter of our correlation list are pair-wise good candidates for prediction of the target variable _SalePrice_. So for now let's pic a few of those as our top candidates for predicting _SalePrice_.
#
#
# Now, we take some of those potential predictor candidates and plot them verus our training data to see if they in fact show signs of correlation. Here we're using the variables _FullBath_, _1stFlrSF_, and _YearBuilt_, because they seem to have low pair-wise correlation and they are attributes that almost all houses should have. **Note:** the fact that we chose three variables was arbitrary.

# %%
from pandas.plotting import scatter_matrix

attributes = ['SalePrice', 'FullBath', 'YearBuilt', '1stFlrSF']
scatter_matrix(df_train[attributes], figsize=a4_dims);

# %% [markdown]
# Are housing _SalePrice_ appeart to be linear with first floor square footage, linear with number of full bathrooms, but there does appear to be some nonlinear behavior with the year the house was built. Instead we may choose to use a similar more well behaved variable that's related to _YearBuilt_, specifically, _YrSold_:

# %%
scatter_matrix(df_train[['SalePrice', 'YrSold']], figsize=a4_dims);

# %% [markdown]
# But apparently we don't have good data on year the house was sold (it was generated in a mathematically continuous manner)! So we'll have to figure out a way to treat our nonlinear year built variable.

# %% [markdown]
# ## First Shot at Regression
#
# We'll take our candidate variables and run a more formal version of regression. Then see how close our predictions are to some test data.

# %%
from sklearn.linear_model import LinearRegression

print("Variables as matrix A: ")
print(df_train[attributes[1:]].head())
A = np.matrix(df_train[attributes[1:]].values)
print()
print("A dimensions: %s" % (A.shape,))
y = np.array((df_train.SalePrice.values).reshape(-1,1))
print("y dimensions: %s =  SalePrice" % (y.shape,))
print()

lin_reg = LinearRegression();
lin_reg.fit(A, y);
coeffs = []
yint = lin_reg.intercept_
coeffs.append(lin_reg.coef_[0][0])
coeffs.append(lin_reg.coef_[0][1])
coeffs.append(lin_reg.coef_[0][2])
coeffs = np.array(coeffs)
print("Regression model: y = %.2f + %.2fx_1 + %.2fx_2 + %.2fx_3" % (yint, coeffs[0], coeffs[1], coeffs[2]))
print()

predictions = lin_reg.predict(A)
e = RMSE(predictions, y)
print("Root Mean Square Error: " + "${:,.2f}".format(e) + '\n')
# Out:
# Variables as matrix A:
#    FullBath  YearBuilt  1stFlrSF
# 0         2       2003       856
# 1         2       1976      1262
# 2         2       2001       920
# 3         1       1915       961
# 4         2       2000      1145
#
# A dimensions: (1460, 3)
# y dimensions: (1460, 1) =  SalePrice
#
# Regression model: y = -1417464.30 + 38800.61x_1 + 728.49x_2 + 87.40x_3
#
# Root Mean Square Error: $53,073.49

# %% [markdown]
# Cool, so we beat our simple averaging technique by abot $25k. Let's tune our model a little bit.
#
# ---
#
# #### Greedy Alteration
#
# Let's pick our predictor variables in a slightly smarter way -- a greedy way. Looking back at the heat map, we notice that _OverallQual_ (overall quality) is most strongly correlated with housing sale price. So let's make that our main predictor variable. We check our correlation data to match overall quality with it's lowest correlated variable:

# %%
print("Overall Quality Correlations: \n")
c = corr.loc['OverallQual'].abs().sort_values(kind="quicksort")
print(c[:18])
print()

print("Saleprice Correlation: \n")
s = corr.loc['SalePrice'].abs().sort_values(kind="quicksort")
print(s[-18:])
# Out:
# Overall Quality Correlations:
#
# LowQualFinSF     0.008118
# YrSold           0.008903
# 3SsnPorch        0.017331
# BsmtHalfBath     0.053283
# ScreenPorch      0.055296
# MiscVal          0.062064
# BsmtFinSF2       0.068506
# MoSold           0.079895
# PoolArea         0.080131
# BedroomAbvGr     0.094882
# BsmtFullBath     0.126834
# EnclosedPorch    0.144344
# OverallCond      0.163157
# LotArea          0.167525
# KitchenAbvGr     0.178735
# LotFrontage      0.241322
# BsmtFinSF1       0.249500
# HalfBath         0.251690
# Name: OverallQual, dtype: float64
#
# Saleprice Correlation:
#
# WoodDeckSF      0.336855
# OpenPorchSF     0.343354
# LotFrontage     0.344270
# BsmtFinSF1      0.390301
# Fireplaces      0.461873
# MasVnrArea      0.488658
# GarageYrBlt     0.504753
# YearRemodAdd    0.521253
# YearBuilt       0.525394
# TotRmsAbvGrd    0.547067
# FullBath        0.566627
# 1stFlrSF        0.607969
# TotalBsmtSF     0.615612
# GarageArea      0.619330
# ...

# %% [markdown]
# For our second variable we choose _LotFrontage_ (linear feet of street connected to property) since it has a small correlation with with overall quality but a slightly stronger correlation with housing price. Let's see what kind of error we get with that thinking:

# %%
print("Variables as matrix A: ")
print(df_train_num[['OverallQual', 'LotFrontage']].head())
A = np.matrix(df_train_num[['OverallQual', 'LotFrontage']].values)
print()
print("A dimensions: %s" % (A.shape,))
y = np.array((df_train_num.SalePrice.values).reshape(-1,1))
print("y dimensions: %s =  SalePrice" % (y.shape,))
print()

lin_reg = LinearRegression();
lin_reg.fit(A, y);
coeffs = []
yint = lin_reg.intercept_
coeffs.append(lin_reg.coef_[0][0])
coeffs.append(lin_reg.coef_[0][1])
coeffs = np.array(coeffs)
print("Regression model: y = %.2f + %.2fx_1 + %.2fx_2" % (yint, coeffs[0], coeffs[1]))
print()

predictions = lin_reg.predict(A)
e = RMSE(predictions, y)
print("Root Mean Square Error: " + "${:,.2f}".format(e) + '\n')
# Out:
# Variables as matrix A:
#    OverallQual  LotFrontage
# 0            7         65.0
# 1            6         80.0
# 2            7         68.0
# 3            7         60.0
# 4            8         84.0
#
# A dimensions: (1121, 2)
# y dimensions: (1121, 1) =  SalePrice
#
# Regression model: y = -136853.43 + 45622.50x_1 + 551.03x_2
#
# Root Mean Square Error: $48,299.56

# %% [markdown]
# Ahh... a little better but still not a smart way to choose variables. But a last manual choice of variables, just for fun:

# %%
print("Variables as matrix A: ")
print(df_train[['GrLivArea', 'YearBuilt', 'BsmtFullBath']].head())
A = np.matrix(df_train[['GrLivArea', 'YearBuilt', 'BsmtFullBath']].values)
print()
print("A dimensions: %s" % (A.shape,))
y = np.array((df_train.SalePrice.values).reshape(-1,1))
print("y dimensions: %s =  SalePrice" % (y.shape,))
print()

lin_reg = LinearRegression();
lin_reg.fit(A, y);
coeffs = []
yint = lin_reg.intercept_
coeffs.append(lin_reg.coef_[0][0])
coeffs.append(lin_reg.coef_[0][1])
coeffs.append(lin_reg.coef_[0][2])
coeffs = np.array(coeffs)
print("Regression model: y = %.2f + %.2fx_1 + %.2fx_2 + %.2fx_3" % (yint, coeffs[0], coeffs[1], coeffs[2]))
print()

predictions = lin_reg.predict(A)
e = RMSE(predictions, y)
print("Root Mean Square Error: " + "${:,.2f}".format(e) + '\n')
# Out:
# Variables as matrix A:
#    GrLivArea  YearBuilt  BsmtFullBath
# 0       1710       2003             1
# 1       1262       1976             0
# 2       1786       2001             1
# 3       1717       1915             1
# 4       2198       2000             1
#
# A dimensions: (1460, 3)
# y dimensions: (1460, 1) =  SalePrice
#
# Regression model: y = -1901839.05 + 95.22x_1 + 978.88x_2 + 20723.62x_3
#
# Root Mean Square Error: $45,505.11

# %% [markdown]
# That's the best we can probably do by a small scale manual inspection.

# %% [markdown]
# ## Standardizing (Preprocessing)
#
# In order to employ many machine learning algorithms our feature values have the same scale (source = Geron, p. 67). We'll use sklearn's preprocessing package.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
